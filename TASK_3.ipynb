# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import random
from selenium.webdriver.common.keys import Keys
import warnings
warnings.filterwarnings("ignore")

# %%
chrome = webdriver.Chrome(ChromeDriverManager().install())
url="https://www.yoshops.com/"
chrome.get(url)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 100.0.4896
# Get LATEST chromedriver version for 100.0.4896 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/100.0.4896.60/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\admin\.wdm\drivers\chromedriver\win32\100.0.4896.60]

# %%
import pyautogui
import time

# %%
comments = ["Dear Customer. Thanks for your feedback, Keep Shopping"]

# %%
from selenium.webdriver.chrome.service import Service
import time
s=Service("C:\\Users\\admin\\chromedriver.exe")
browser = webdriver.Chrome(service=s)

# %%
url="https://yoshops.com/products?page=1" 
browser.get(url)
time.sleep(5)

# %%
productNames = browser.find_elements_by_xpath("//span[@class='product-title']")

# %%
time.sleep(5)

# %%
productLinks = browser.find_elements_by_xpath("//a[@class='product-link']")

# %%
links=[]
names=[]
for i in range(len(productLinks)):
    product_link = productLinks[i].get_attribute('href')
    product_name = productNames[i].text
    links.append(product_link)
    names.append(product_name)

# %%
browser.get(links[0])

# %%
time.sleep(5)

# %%
customer_name=browser.find_elements_by_xpath("//span[@class='y-label yotpo-user-name yotpo-font-bold pull-left']")

# %%
customer_name[1].text
# Out:
# 'SudhagarSvS'

# %%
time.sleep(5)

# %%
reviewButton=browser.find_element_by_xpath("//span[@class='yotpo-icon-button-text']")

# %%
browser.execute_script("arguments[0].click();", reviewButton)

# %%
titleField = browser.find_element_by_id("yotpo_input_review_title_934850e3-94a6-468c-b046-11c8dad4585b")

# %%
reviewField = browser.find_element_by_id("yotpo_input_review_content_934850e3-94a6-468c-b046-11c8dad4585b")

# %%
userIDField = browser.find_element_by_id("yotpo_input_review_username_934850e3-94a6-468c-b046-11c8dad4585b")

# %%
emailIDField = browser.find_element_by_id("yotpo_input_review_email_934850e3-94a6-468c-b046-11c8dad4585b")

# %%
titleField.send_keys('Thank You!')

# %%
reviewField.send_keys('Dear Customer, Thankyou for the feedback, keep shopping')

# %%
userIDField.send_keys('Yoshops')

# %%
emailIDField.send_keys('sabitalangkam.yoshops@gmail.com')

# %%
starRating = browser.find_element_by_xpath("//span[@class='yotpo-icon pull-left review-star yotpo-icon-empty-star']")

# %%
browser.execute_script("arguments[0].click();", starRating)

# %%
time.sleep(5)
postButton=browser.find_element_by_xpath("//input[@class='yotpo-default-button primary-color-btn yotpo-submit']")

# %%
browser.execute_script("arguments[0].click();", postButton)

# %% [markdown]
# ![Screenshot%20%2819%29.png](attachment:Screenshot%20%2819%29.png)
